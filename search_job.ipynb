# %%
from jobspy import scrape_jobs

# %%
params = {
    "site_name": ["linkedin"],  # "indeed", "linkedin", etc
    "search_term": ["data scientist", "machine learning engineer"],
    "location": "United States",
    "industry": ["energy", "oil & gas", "software development"],
    "job_type": ["full-time"],  # "part-time", "internship"
    # "experience_level": ["entry level", "mid level"],  # "senior level", "director", "executive"
    # "salary_range": (70000, 150000),  # (min_salary, max_salary)
    "date_posted": "",
}

# %%
jobs = scrape_jobs(
    site_name=["indeed", "linkedin", "zip_recruiter", "google"], # "glassdoor", "bayt", "naukri", "bdjobs"
    search_term="software engineer",
    google_search_term="software engineer jobs near San Francisco, CA since yesterday",
    location="San Francisco, CA",
    results_wanted=20,
    hours_old=72,
    country_indeed='USA',
    
    # linkedin_fetch_description=True # gets more info such as description, direct job url (slower)
    # proxies=["208.195.175.46:65095", "208.195.175.45:65095", "localhost"],
)
print(f"Found {len(jobs)} jobs")
print(jobs.head())
# jobs.to_csv("jobs.csv", quoting=csv.QUOTE_NONNUMERIC, escapechar="\\", index=False) # to_excel
# Out:
# 2026-02-05 12:18:13,949 - INFO - JobSpy:Linkedin - finished scraping
# Found 40 jobs
#                     id    site  \
# 0  in-131964dcc1c385b5  indeed
# 1  in-9a0bceeaf83ea426  indeed
# 2  in-51049ef671344fb5  indeed
# 3  in-77905fc2cd01126e  indeed
# 4  in-487937f057be8f76  indeed
#
#                                              job_url  \
# 0  https://www.indeed.com/viewjob?jk=131964dcc1c3...
# 1  https://www.indeed.com/viewjob?jk=9a0bceeaf83e...
# 2  https://www.indeed.com/viewjob?jk=51049ef67134...
# 3  https://www.indeed.com/viewjob?jk=77905fc2cd01...
# 4  https://www.indeed.com/viewjob?jk=487937f057be...
#
#                                       job_url_direct  \
# 0  https://ats.rippling.com/patronus-ai-jobs/jobs...
# 1  https://jobs.smartrecruiters.com/SquareTrade1/...
# 2  https://jobs.lever.co/weekdayworks/50ee8dbc-96...
# 3  https://jobs.lever.co/goodleap/805c9a7b-fa67-4...
# 4  https://jobs.lever.co/goodleap/805c9a7b-fa67-4...
#
# ...

# %%
jobs
# Out:
#                      id      site  \
# 0   in-131964dcc1c385b5    indeed
# 1   in-9a0bceeaf83ea426    indeed
# 2   in-51049ef671344fb5    indeed
# 3   in-77905fc2cd01126e    indeed
# 4   in-487937f057be8f76    indeed
# 5   in-2ac87261deec44f5    indeed
# 6   in-83904013752589e8    indeed
# 7   in-cab58ffd1bba0243    indeed
# 8   in-46043acc9b31f851    indeed
# 9   in-51c9f77ae6160699    indeed
# 10  in-139da281ace7578c    indeed
# 11  in-f52b7e4d2ca2eb7d    indeed
# 12  in-f7b0d028073ea765    indeed
# 13  in-4fcf5f9473a46c8b    indeed
# 14  in-ca550c999210685b    indeed
# 15  in-1328c1ebb080674f    indeed
# 16  in-99a4c22994ffff42    indeed
# 17  in-fc9050b4e89112d1    indeed
# 18  in-211dec7bafe5dbbc    indeed
# 19  in-bd665ac5d04aa968    indeed
# 20        li-4328991042  linkedin
# 21        li-4361551460  linkedin
# 22        li-4204412244  linkedin
# 23        li-4368551699  linkedin
# 24        li-4287339353  linkedin
# 25        li-4368734192  linkedin
# ...

# %%
jobs.iloc[0]
# Out:
# id                                                     in-131964dcc1c385b5
# site                                                                indeed
# job_url                  https://www.indeed.com/viewjob?jk=131964dcc1c3...
# job_url_direct           https://ats.rippling.com/patronus-ai-jobs/jobs...
# title                        Member of Technical Staff - Software Engineer
# company                                                        Patronus AI
# location                                             San Francisco, CA, US
# date_posted                                                     2026-02-05
# job_type                                                          fulltime
# salary_source                                                          NaN
# interval                                                               NaN
# min_amount                                                             NaN
# ...
